# %%
import pandas as pd

# %%
df_primary=pd.read_csv(r'C:\Users\hrithiks\Downloads\CAR_CRASH_ANALYSIS\Data\Primary_Person_use.csv')
df_units=pd.read_csv(r'C:\Users\hrithiks\Downloads\CAR_CRASH_ANALYSIS\Data\Units_use.csv')
df_damage=pd.read_csv(r'C:\Users\hrithiks\Downloads\CAR_CRASH_ANALYSIS\Data\Damages_use.csv')
df_charge=pd.read_csv(r'C:\Users\hrithiks\Downloads\CAR_CRASH_ANALYSIS\Data\Charges_use.csv')
# Out:
# C:\Users\hrithiks\AppData\Local\Temp\ipykernel_25320\4269976760.py:2: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_units=pd.read_csv(r'C:\Users\hrithiks\Downloads\CAR_CRASH_ANALYSIS\Data\Units_use.csv')

# %%
df_primary.head(25)
# Out:
#     CRASH_ID  UNIT_NBR  PRSN_NBR PRSN_TYPE_ID PRSN_OCCPNT_POS_ID  \
# 0   14768622         1         1       DRIVER         FRONT LEFT
# 1   14838637         1         1       DRIVER         FRONT LEFT
# 2   14838637         2         1       DRIVER         FRONT LEFT
# 3   14838641         1         1       DRIVER         FRONT LEFT
# 4   14838641         2         1       DRIVER         FRONT LEFT
# 5   14838668         1         1       DRIVER         FRONT LEFT
# 6   14838669         1         1       DRIVER         FRONT LEFT
# 7   14838669         2         1       DRIVER         FRONT LEFT
# 8   14838670         1         1       DRIVER         FRONT LEFT
# 9   14838685         1         1       DRIVER         FRONT LEFT
# 10  14838693         1         1       DRIVER         FRONT LEFT
# 11  14838768         1         1       DRIVER         FRONT LEFT
# 12  14838768         2         1       DRIVER         FRONT LEFT
# ...

# %%
df_primary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156954 entries, 0 to 156953
# Data columns (total 32 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   CRASH_ID               156954 non-null  int64
#  1   UNIT_NBR               156954 non-null  int64
#  2   PRSN_NBR               156954 non-null  int64
#  3   PRSN_TYPE_ID           156954 non-null  object
#  4   PRSN_OCCPNT_POS_ID     156954 non-null  object
#  5   PRSN_INJRY_SEV_ID      156935 non-null  object
#  6   PRSN_AGE               154924 non-null  float64
#  7   PRSN_ETHNICITY_ID      156680 non-null  object
#  8   PRSN_GNDR_ID           156935 non-null  object
#  9   PRSN_EJCT_ID           156935 non-null  object
#  10  PRSN_REST_ID           156935 non-null  object
#  11  PRSN_AIRBAG_ID         156935 non-null  object
#  12  PRSN_HELMET_ID         156954 non-null  object
#  13  PRSN_SOL_FL            156935 non-null  object
# ...

# %%
df_primary['UNIT_NBR'].isnull().sum()
# Out:
# 0

# %%
df_primary['PRSN_NBR'].isnull().sum()
# Out:
# 0

# %%
df_primary['PRSN_NBR'].value_counts()
# Out:
# 1    156954
# Name: PRSN_NBR, dtype: int64

# %%
df_primary['PRSN_TYPE_ID'].value_counts()
# Out:
# DRIVER                               154798
# DRIVER OF MOTORCYCLE TYPE VEHICLE       755
# PEDESTRIAN                              515
# PASSENGER/OCCUPANT                      505
# UNKNOWN                                 195
# PEDALCYCLIST                            156
# OTHER (EXPLAIN IN NARRATIVE)             30
# Name: PRSN_TYPE_ID, dtype: int64

# %%
df_primary['PRSN_OCCPNT_POS_ID'].value_counts()
# Out:
# FRONT LEFT                                           155768
# PEDESTRIAN, PEDALCYCLIST, OR MOTORIZED CONVEYANCE       679
# UNKNOWN                                                 152
# OUTSIDE VEHICLE                                         115
# FRONT RIGHT                                             105
# FRONT CENTER                                             69
# OTHER IN VEHICLE                                         23
# OTHER  (EXPLAIN IN NARRATIVE)                            11
# SECOND SEAT RIGHT                                         8
# SECOND SEAT LEFT                                          8
# CARGO AREA                                                6
# PASSENGER IN BUS                                          5
# SECOND SEAT CENTER                                        3
# THIRD SEAT LEFT                                           2
# Name: PRSN_OCCPNT_POS_ID, dtype: int64

# %%
df_primary['PRSN_INJRY_SEV_ID'].value_counts()
# Out:
# NOT INJURED                  120752
# POSSIBLE INJURY               18752
# NON-INCAPACITATING INJURY     11850
# INCAPACITATING INJURY          2674
# UNKNOWN                        2661
# KILLED                          246
# Name: PRSN_INJRY_SEV_ID, dtype: int64

# %%
df_primary['PRSN_ETHNICITY_ID'].value_counts()
# Out:
# WHITE                          71099
# HISPANIC                       52791
# BLACK                          23205
# ASIAN                           4539
# OTHER                           3298
# UNKNOWN                         1543
# AMER. INDIAN/ALASKAN NATIVE      205
# Name: PRSN_ETHNICITY_ID, dtype: int64

# %%
df_primary['PRSN_EJCT_ID'].value_counts()
# Out:
# NO                151559
# NOT APPLICABLE      3797
# UNKNOWN             1076
# YES                  451
# YES, PARTIAL          52
# Name: PRSN_EJCT_ID, dtype: int64

# %%
df_primary['PRSN_REST_ID'].value_counts()
# Out:
# SHOULDER & LAP BELT             144505
# UNKNOWN                           7638
# NONE                              2091
# NOT APPLICABLE                    1865
# SHOULDER BELT ONLY                 652
# LAP BELT ONLY                      125
# OTHER (EXPLAIN IN NARRATIVE)        36
# CHILD SEAT, UNKNOWN                 16
# CHILD SEAT, FACING FORWARD           4
# CHILD BOOSTER SEAT                   2
# CHILD SEAT, FACING REAR              1
# Name: PRSN_REST_ID, dtype: int64

# %%
df_primary['PRSN_AIRBAG_ID'].value_counts()
# Out:
# NOT DEPLOYED         118967
# DEPLOYED, FRONT       21149
# DEPLOYED MULTIPLE      7792
# NOT APPLICABLE         3910
# DEPLOYED, SIDE         2811
# UNKNOWN                2291
# DEPLOYED, REAR           15
# Name: PRSN_AIRBAG_ID, dtype: int64

# %%
df_primary['PRSN_HELMET_ID'].value_counts()
# Out:
# NOT APPLICABLE       156043
# NOT WORN                457
# WORN, DAMAGED           188
# WORN, NOT DAMAGED       161
# WORN, UNK DAMAGE         72
# UNKNOWN IF WORN          33
# Name: PRSN_HELMET_ID, dtype: int64

# %%
df_primary['PRSN_SOL_FL'].value_counts()
# Out:
# N    156100
# Y       835
# Name: PRSN_SOL_FL, dtype: int64

# %%
df_primary['PRSN_ALC_SPEC_TYPE_ID'].value_counts()
# Out:
# NONE                            144393
# BLOOD                             6690
# BREATH                            4369
# REFUSED                           1126
# OTHER (EXPLAIN IN NARRATIVE)       336
# URINE                               21
# Name: PRSN_ALC_SPEC_TYPE_ID, dtype: int64

# %%
df_primary['PRSN_ALC_RSLT_ID'].value_counts()
# Out:
# Positive    7028
# Negative    1215
# Name: PRSN_ALC_RSLT_ID, dtype: int64

# %%
df_primary['PRSN_BAC_TEST_RSLT'].value_counts()
# Out:
# 0.000    755
# 0.170    195
# 0.180    187
# 0.150    168
# 0.190    167
#         ...
# 0.427      1
# 0.386      1
# 0.423      1
# 0.380      1
# 0.830      1
# Name: PRSN_BAC_TEST_RSLT, Length: 390, dtype: int64

# %%
df_primary['PRSN_DRG_SPEC_TYPE_ID'].value_counts()
# Out:
# NONE                            152527
# BLOOD                             3462
# REFUSED                            642
# OTHER (EXPLAIN IN NARRATIVE)       254
# URINE                               50
# Name: PRSN_DRG_SPEC_TYPE_ID, dtype: int64

# %%
df_primary['DRVR_DRG_CAT_1_ID'].value_counts()
# Out:
# NOT APPLICABLE                           154100
# UNKNOWN                                    2214
# MULTIPLE DRUGS (EXPLAIN IN NARRATIVE)       272
# CNS DEPRESSANTS                             105
# CNS STIMULANTS                               88
# CANNABIS                                     83
# OTHER DRUGS (EXPLAIN IN NARRATIVE)           34
# NARCOTIC ANALGESICS                          18
# DISSOCIATIVE ANESTHETICS                     10
# HALLUCINOGENS                                 9
# INHALANTS                                     2
# Name: DRVR_DRG_CAT_1_ID, dtype: int64

# %%
df_primary['INCAP_INJRY_CNT'].value_counts()
# Out:
# 0    154280
# 1      2674
# Name: INCAP_INJRY_CNT, dtype: int64

# %%
df_primary['NONINCAP_INJRY_CNT'].value_counts()
# Out:
# 0    145104
# 1     11850
# Name: NONINCAP_INJRY_CNT, dtype: int64

# %%
df_primary['POSS_INJRY_CNT'].value_counts()
# Out:
# 0    138202
# 1     18752
# Name: POSS_INJRY_CNT, dtype: int64

# %%
df_primary['NON_INJRY_CNT'].value_counts()
# Out:
# 1    120752
# 0     36202
# Name: NON_INJRY_CNT, dtype: int64

# %%
df_primary['UNKN_INJRY_CNT'].value_counts()
# Out:
# 0    154274
# 1      2680
# Name: UNKN_INJRY_CNT, dtype: int64

# %%
df_primary['TOT_INJRY_CNT'].value_counts()
# Out:
# 0    123678
# 1     33276
# Name: TOT_INJRY_CNT, dtype: int64

# %%
df_primary['DEATH_CNT'].value_counts()
# Out:
# 0    156708
# 1       246
# Name: DEATH_CNT, dtype: int64

# %%
df_primary['DRVR_LIC_TYPE_ID'].value_counts()
# Out:
# DRIVER LICENSE            125226
# ID CARD                    11924
# UNLICENSED                  8988
# COMMERCIAL DRIVER LIC.      7204
# UNKNOWN                     2268
# OTHER                        354
# OCCUPATIONAL                 124
# Name: DRVR_LIC_TYPE_ID, dtype: int64

# %%
df_primary['DRVR_LIC_STATE_ID'].value_counts()
# Out:
# Texas                       136335
# Unknown                       2268
# Mexico                        1007
# Louisiana                      752
# New Mexico                     699
#                              ...
# Rhode Island                     5
# Northern Mariana Islands         2
# U.S. Virgin Islands              1
# Wake Island                      1
# Guam                             1
# Name: DRVR_LIC_STATE_ID, Length: 61, dtype: int64

# %%
df_primary['DRVR_LIC_CLS_ID'].value_counts()
# Out:
# CLASS C               110811
# UNLICENSED             21117
# OTHER/OUT OF STATE      7933
# CLASS A                 7079
# CLASS C AND M           4093
# UNKNOWN                 2401
# CLASS B                 1504
# CLASS A AND M            909
# CLASS B AND M            223
# CLASS M                   18
# Name: DRVR_LIC_CLS_ID, dtype: int64

# %%
import numpy as np

# %%
l=df_primary.groupby(['DRVR_LIC_STATE_ID','PRSN_ETHNICITY_ID'])

# %%
l.first()
# Out:
#                                      CRASH_ID  UNIT_NBR  PRSN_NBR  \
# DRVR_LIC_STATE_ID PRSN_ETHNICITY_ID
# Alabama           BLACK              14858440         2         1
#                   HISPANIC           14868304         1         1
#                   OTHER              14997532         1         1
#                   UNKNOWN            15211756         2         1
#                   WHITE              14847859         1         1
# ...                                       ...       ...       ...
# Wisconsin         HISPANIC           14862775         2         1
#                   OTHER              15405529         2         1
#                   WHITE              14851073         2         1
# Wyoming           HISPANIC           14963218         1         1
#                   WHITE              14868982         1         1
#
#                                     PRSN_TYPE_ID PRSN_OCCPNT_POS_ID  \
# DRVR_LIC_STATE_ID PRSN_ETHNICITY_ID
# ...

# %%
#to analyse state wise and ethnic wise person injury count

# %%
p=df_primary.groupby(['DRVR_LIC_STATE_ID','PRSN_ETHNICITY_ID','PRSN_INJRY_SEV_ID']).count()

# %%
p
# Out:
#                                                                CRASH_ID  \
# DRVR_LIC_STATE_ID PRSN_ETHNICITY_ID PRSN_INJRY_SEV_ID
# Alabama           BLACK             INCAPACITATING INJURY             1
#                                     NOT INJURED                      30
#                                     POSSIBLE INJURY                   2
#                   HISPANIC          NON-INCAPACITATING INJURY         1
#                                     NOT INJURED                       9
# ...                                                                 ...
# Wisconsin         WHITE             UNKNOWN                           1
# Wyoming           HISPANIC          NOT INJURED                       1
#                   WHITE             INCAPACITATING INJURY             1
#                                     NON-INCAPACITATING INJURY         1
#                                     NOT INJURED                      14
#
# ...

# %%
l.first()['PRSN_INJRY_SEV_ID']!='NOT INJURED'
# Out:
# DRVR_LIC_STATE_ID  PRSN_ETHNICITY_ID
# Alabama            BLACK                False
#                    HISPANIC             False
#                    OTHER                False
#                    UNKNOWN              False
#                    WHITE                False
#                                         ...
# Wisconsin          HISPANIC             False
#                    OTHER                False
#                    WHITE                False
# Wyoming            HISPANIC             False
#                    WHITE                False
# Name: PRSN_INJRY_SEV_ID, Length: 268, dtype: bool

# %%
#to filter male from df_primary

# %%
df_male=df_primary[df_primary['PRSN_GNDR_ID']=='MALE']

# %%
#to get the male which were killed

# %%
df_male[df_male['PRSN_INJRY_SEV_ID']=='KILLED']
# Out:
#         CRASH_ID  UNIT_NBR  PRSN_NBR PRSN_TYPE_ID  \
# 1187    14848300         2         1       DRIVER
# 2079    14851818         2         1       DRIVER
# 2121    14851954         2         1       DRIVER
# 2314    14852533         2         1   PEDESTRIAN
# 2644    14854567         3         1       DRIVER
# ...          ...       ...       ...          ...
# 153982  15502739         2         1   PEDESTRIAN
# 154124  15503748         1         1       DRIVER
# 154489  15506999         1         1       DRIVER
# 154992  15511556         1         1       DRIVER
# 155420  15515080         2         1   PEDESTRIAN
#
#                                        PRSN_OCCPNT_POS_ID PRSN_INJRY_SEV_ID  \
# 1187                                           FRONT LEFT            KILLED
# 2079                                           FRONT LEFT            KILLED
# 2121                                           FRONT LEFT            KILLED
# ...

# %%
df_male[df_male['PRSN_INJRY_SEV_ID']=='KILLED'].shape[0] #getting the count of the no of males that were killed.
# Out:
# 182

# %%
df_primary['DRVR_LIC_STATE_ID'].count()
# Out:
# 147100

# %%
df_primary.groupby(['DRVR_LIC_STATE_ID']).count()
# Out:
#                           CRASH_ID  UNIT_NBR  PRSN_NBR  PRSN_TYPE_ID  \
# DRVR_LIC_STATE_ID
# Alabama                        135       135       135           135
# Alaska                          29        29        29            29
# American Samoa (Islands)         7         7         7             7
# Arizona                        256       256       256           256
# Arkansas                       344       344       344           344
# ...                            ...       ...       ...           ...
# Wake Island                      1         1         1             1
# Washington                     127       127       127           127
# West Virginia                   15        15        15            15
# Wisconsin                       76        76        76            76
# Wyoming                         17        17        17            17
#
#                           PRSN_OCCPNT_POS_ID  PRSN_INJRY_SEV_ID  PRSN_AGE  \
# DRVR_LIC_STATE_ID
# ...

# %%
maxCrashState = df_primary.groupby(['DRVR_LIC_STATE_ID']).count().sort_values(by='CRASH_ID',ascending=False).reset_index().iloc[0]['DRVR_LIC_STATE_ID']

# %%
stateGenderFreqDf = df_primary[df_primary['DRVR_LIC_STATE_ID']==maxCrashState].groupby('PRSN_GNDR_ID').count()['CRASH_ID'].reset_index()

# %%
stateGenderFreqDf[stateGenderFreqDf['PRSN_GNDR_ID']=='FEMALE']['CRASH_ID'][0]
# Out:
# 53319

# %%
df_units_clean=df_units.dropna(subset=['VEH_BODY_STYL_ID'])

# %%
df_units_clean=df_units_clean[~df_units_clean['VEH_BODY_STYL_ID'].isin(["UNKNOWN", "NOT REPORTED","OTHER  (EXPLAIN IN NARRATIVE)"])]

# %%
df_units_clean
# Out:
#         CRASH_ID  UNIT_NBR   UNIT_DESC_ID VEH_PARKED_FL VEH_HNR_FL  \
# 0       14768622         1  MOTOR VEHICLE             N          N
# 1       14838637         1  MOTOR VEHICLE             N          N
# 2       14838637         2  MOTOR VEHICLE             N          N
# 3       14838637         2  MOTOR VEHICLE             N          N
# 5       14838641         1  MOTOR VEHICLE             N          N
# ...          ...       ...            ...           ...        ...
# 173494  15700059         2  MOTOR VEHICLE             N          N
# 173495  15700059         3  MOTOR VEHICLE             N          N
# 173496  15700064         1  MOTOR VEHICLE             N          N
# 173497  15700064         2  MOTOR VEHICLE             N          N
# 173498  15712435         1  MOTOR VEHICLE             N          Y
#
#        VEH_LIC_STATE_ID                VIN  VEH_MOD_YEAR VEH_COLOR_ID  \
# 0                    TX  4S2CK57D1X4381118        1999.0          GRY
# ...

# %%
df_primary_clean=df_primary.dropna(subset=['PRSN_ETHNICITY_ID'])

# %%
df_primary_clean=df_primary_clean[~df_primary_clean['PRSN_ETHNICITY_ID'].isin(["UNKNOWN"])]

# %%
df_primary_clean
# Out:
#         CRASH_ID  UNIT_NBR  PRSN_NBR PRSN_TYPE_ID PRSN_OCCPNT_POS_ID  \
# 0       14768622         1         1       DRIVER         FRONT LEFT
# 1       14838637         1         1       DRIVER         FRONT LEFT
# 2       14838637         2         1       DRIVER         FRONT LEFT
# 3       14838641         1         1       DRIVER         FRONT LEFT
# 4       14838641         2         1       DRIVER         FRONT LEFT
# ...          ...       ...       ...          ...                ...
# 156949  15700059         2         1       DRIVER         FRONT LEFT
# 156950  15700059         3         1       DRIVER         FRONT LEFT
# 156951  15700064         1         1       DRIVER         FRONT LEFT
# 156952  15700064         2         1       DRIVER         FRONT LEFT
# 156953  15712435         1         1       DRIVER         FRONT LEFT
#
#                 PRSN_INJRY_SEV_ID  PRSN_AGE PRSN_ETHNICITY_ID PRSN_GNDR_ID  \
# ...

# %%
df_merged=pd.merge(df_units_clean,df_primary_clean, on='CRASH_ID')

# %%
df_merged.columns
# Out:
# Index(['CRASH_ID', 'UNIT_NBR_x', 'UNIT_DESC_ID', 'VEH_PARKED_FL', 'VEH_HNR_FL',
#        'VEH_LIC_STATE_ID', 'VIN', 'VEH_MOD_YEAR', 'VEH_COLOR_ID',
#        'VEH_MAKE_ID', 'VEH_MOD_ID', 'VEH_BODY_STYL_ID', 'EMER_RESPNDR_FL',
#        'OWNR_ZIP', 'FIN_RESP_PROOF_ID', 'FIN_RESP_TYPE_ID',
#        'VEH_DMAG_AREA_1_ID', 'VEH_DMAG_SCL_1_ID', 'FORCE_DIR_1_ID',
#        'VEH_DMAG_AREA_2_ID', 'VEH_DMAG_SCL_2_ID', 'FORCE_DIR_2_ID',
#        'VEH_INVENTORIED_FL', 'VEH_TRANSP_NAME', 'VEH_TRANSP_DEST',
#        'CONTRIB_FACTR_1_ID', 'CONTRIB_FACTR_2_ID', 'CONTRIB_FACTR_P1_ID',
#        'VEH_TRVL_DIR_ID', 'FIRST_HARM_EVT_INV_ID', 'INCAP_INJRY_CNT_x',
#        'NONINCAP_INJRY_CNT_x', 'POSS_INJRY_CNT_x', 'NON_INJRY_CNT_x',
#        'UNKN_INJRY_CNT_x', 'TOT_INJRY_CNT_x', 'DEATH_CNT_x', 'UNIT_NBR_y',
#        'PRSN_NBR', 'PRSN_TYPE_ID', 'PRSN_OCCPNT_POS_ID', 'PRSN_INJRY_SEV_ID',
#        'PRSN_AGE', 'PRSN_ETHNICITY_ID', 'PRSN_GNDR_ID', 'PRSN_EJCT_ID',
# ...

# %%
df_merged.groupby(['VEH_BODY_STYL_ID','PRSN_ETHNICITY_ID']).count() # vechicle body style , person ethnicity count
# Out:
#                                      CRASH_ID  UNIT_NBR_x  UNIT_DESC_ID  \
# VEH_BODY_STYL_ID  PRSN_ETHNICITY_ID
# AMBULANCE         ASIAN                     3           3             3
#                   BLACK                    32          32            32
#                   HISPANIC                 43          43            43
#                   OTHER                    11          11            11
#                   WHITE                    97          97            97
# ...                                       ...         ...           ...
# YELLOW SCHOOL BUS ASIAN                    14          14            14
#                   BLACK                   177         177           177
#                   HISPANIC                162         162           162
#                   OTHER                     8           8             8
#                   WHITE                   264         264           264
#
#                                      VEH_PARKED_FL  VEH_HNR_FL  \
# ...

# %%
df_units['CONTRIB_FACTR_1_ID'].str.contains('ALCOHOL')
# Out:
# 0          True
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 173494    False
# 173495    False
# 173496    False
# 173497    False
# 173498     True
# Name: CONTRIB_FACTR_1_ID, Length: 173499, dtype: object

# %%
df_units_contrib=df_units[df_units['CONTRIB_FACTR_1_ID'].str.contains('ALCOHOL',na=False) | df_units_contrib_1['CONTRIB_FACTR_2_ID'].str.contains('ALCOHOL')]

# %%
df_units_contrib #dataframe containing contributing factors with alcohol
# Out:
#         CRASH_ID  UNIT_NBR   UNIT_DESC_ID VEH_PARKED_FL VEH_HNR_FL  \
# 0       14768622         1  MOTOR VEHICLE             N          N
# 7       14838668         1  MOTOR VEHICLE             N          N
# 14      14838693         1  MOTOR VEHICLE             N          N
# 25      14838877         1  MOTOR VEHICLE             N          N
# 32      14839047         1  MOTOR VEHICLE             N          N
# ...          ...       ...            ...           ...        ...
# 173422  15630307         1  MOTOR VEHICLE             N          N
# 173443  15630746         1  MOTOR VEHICLE             N          Y
# 173446  15630848         1  MOTOR VEHICLE             N          Y
# 173488  15678581         1  MOTOR VEHICLE             N          N
# 173498  15712435         1  MOTOR VEHICLE             N          Y
#
#        VEH_LIC_STATE_ID                VIN  VEH_MOD_YEAR VEH_COLOR_ID  \
# 0                    TX  4S2CK57D1X4381118        1999.0          GRY
# ...

# %%
df_primary_with_zip=df_primary.dropna(subset=['DRVR_ZIP'])

# %%
df_zip_merged=pd.merge(df_units_contrib,df_primary_with_zip,on ='CRASH_ID')

# %%
df_zip_merged.groupby('DRVR_ZIP').count().sort_values(by='CRASH_ID',ascending=False).reset_index().head(10)
# Out:
#   DRVR_ZIP  CRASH_ID  UNIT_NBR_x  UNIT_DESC_ID  VEH_PARKED_FL  VEH_HNR_FL  \
# 0    78521        45          45            45             45          45
# 1    76010        44          44            44             44          44
# 2    75067        37          37            37             37          37
# 3    78586        31          31            31             31          31
# 4    75052        30          30            30             30          30
# 5    78542        30          30            30             30          30
# 6    78130        30          30            30             30          30
# 7    78572        29          29            29             29          29
# 8    78574        29          29            29             29          29
# 9    75061        29          29            29             29          29
#
#    VEH_LIC_STATE_ID  VIN  VEH_MOD_YEAR  VEH_COLOR_ID  ...  INCAP_INJRY_CNT_y  \
# ...

# %%
#To check damage level is grater than 4 by filtering not present in "NO DAMAGE" or "INVALID VALUE"

# %%
del df_unit_clean_veh_dam

# %%
df_unit_clean_veh_dam=df_units.dropna(subset=(['VEH_DMAG_SCL_1_ID']))
df_unit_clean_veh_dam=df_unit_clean_veh_dam.dropna(subset=(['VEH_DMAG_SCL_2_ID']))

# %%
df_unit_clean_veh_dam=df_unit_clean_veh_dam[((df_unit_clean_veh_dam['VEH_DMAG_SCL_1_ID']>'DAMAGED 4') & (~df_unit_clean_veh_dam['VEH_DMAG_SCL_1_ID'].isin([ "NO DAMAGE", "INVALID VALUE"])))
                                           |((df_unit_clean_veh_dam['VEH_DMAG_SCL_2_ID']>'DAMAGED 4') & (~df_unit_clean_veh_dam['VEH_DMAG_SCL_2_ID'].isin([ "NO DAMAGE", "INVALID VALUE"])))]

# %%
df_unit_clean_veh_dam
# Out:
#         CRASH_ID  UNIT_NBR   UNIT_DESC_ID VEH_PARKED_FL VEH_HNR_FL  \
# 44      14839240         2  MOTOR VEHICLE             N          N
# 86      14839761         1  MOTOR VEHICLE             N          N
# 186     14840537         2  MOTOR VEHICLE             N          N
# 193     14840590         1  MOTOR VEHICLE             N          N
# 268     14841166         1  MOTOR VEHICLE             N          N
# ...          ...       ...            ...           ...        ...
# 173468  15631459         4  MOTOR VEHICLE             Y          N
# 173479  15659351         1  MOTOR VEHICLE             N          N
# 173484  15674881         1  MOTOR VEHICLE             N          N
# 173489  15685852         1  MOTOR VEHICLE             N          N
# 173496  15700064         1  MOTOR VEHICLE             N          N
#
#        VEH_LIC_STATE_ID                VIN  VEH_MOD_YEAR VEH_COLOR_ID  \
# 44                   TX  2B3KA43G67H831063        2007.0          SIL
# ...

# %%
df_unit_clean_veh_dam=df_unit_clean_veh_dam[df_unit_clean_veh_dam['FIN_RESP_TYPE_ID']=="PROOF OF LIABILITY INSURANCE"]
#df_units['FIN_RESP_TYPE_ID']

# %%
df_unit_clean_veh_dam
# Out:
#         CRASH_ID  UNIT_NBR   UNIT_DESC_ID VEH_PARKED_FL VEH_HNR_FL  \
# 44      14839240         2  MOTOR VEHICLE             N          N
# 193     14840590         1  MOTOR VEHICLE             N          N
# 268     14841166         1  MOTOR VEHICLE             N          N
# 275     14841507         1  MOTOR VEHICLE             N          N
# 348     14842185         1  MOTOR VEHICLE             N          Y
# ...          ...       ...            ...           ...        ...
# 173426  15630328         1  MOTOR VEHICLE             N          N
# 173445  15630786         1  MOTOR VEHICLE             N          N
# 173446  15630848         1  MOTOR VEHICLE             N          Y
# 173448  15630969         1  MOTOR VEHICLE             N          N
# 173465  15631459         1  MOTOR VEHICLE             N          N
#
#        VEH_LIC_STATE_ID                VIN  VEH_MOD_YEAR VEH_COLOR_ID  \
# 44                   TX  2B3KA43G67H831063        2007.0          SIL
# ...

# %%
df_damage
# Out:
#        CRASH_ID            DAMAGED_PROPERTY
# 0      14768622                     MAILBOX
# 1      14768622                 YARD, GRASS
# 2      14838668                   GUARDRAIL
# 3      14838685                   ROAD SIGN
# 4      14838693                2009 MAZDA 3
# ...         ...                         ...
# 24945  15631459                     MAILBOX
# 24946  15632416            CONCRETE BARRIER
# 24947  15674881        40 FEET OF GUARDRAIL
# 24948  15678581  UTILITY POLE (UNREADABLE#)
# 24949  15712435                FIRE HYDRANT
#
# [24950 rows x 2 columns]

# %%
df_damage['DAMAGED_PROPERTY'].isnull().sum()
# Out:
# 6

# %%
df_damage_with_none_dam=df_damage[df_damage['DAMAGED_PROPERTY']=='NONE']

# %%
df_damage_with_none_dam
# Out:
#        CRASH_ID DAMAGED_PROPERTY
# 101    14844642             NONE
# 114    14845535             NONE
# 514    14859733             NONE
# 580    14861933             NONE
# 876    14870169             NONE
# ...         ...              ...
# 22045  15437213             NONE
# 22435  15450751             NONE
# 22543  15454348             NONE
# 23747  15615192             NONE
# 23774  15628296             NONE
#
# [93 rows x 2 columns]

# %%
df_top_25_count=df_units.groupby('VEH_LIC_STATE_ID').count().sort_values(by='CRASH_ID',ascending=False).nlargest(25,'CRASH_ID').iloc[:,0]

# %%
df_top_25_count_state=df_top_25_count.index.tolist()

# %%
df_top_25_count_state
# Out:
# ['TX',
#  'UN',
#  'OK',
#  'LA',
#  'NM',
#  'IN',
#  'MX',
#  'CA',
#  'FL',
#  'IL',
#  'AR',
#  'TN',
#  'MS',
#  'AZ',
#  'KS',
#  'GA',
#  'MO',
#  'CO',
#  'NC',
#  'AL',
#  'OH',
#  'MI',
#  'MN',
#  '98',
#  'WI']

# %%
df_top_10_color

# %%
df_units_color =df_units.dropna(subset=['VEH_COLOR_ID'])

# %%
df_top_10_color=df_units_color.groupby('VEH_COLOR_ID').count().sort_values(by='CRASH_ID',ascending=False).nlargest(10,'CRASH_ID').iloc[:,0]

# %%
df_top_10_color=df_top_10_color.index.tolist()

# %%
df_top_10_color
# Out:
# ['WHI', 'BLK', 'SIL', 'GRY', 'BLU', 'RED', 'GRN', 'MAR', 'TAN', 'GLD']

# %%
df_with_license=df_primary[df_primary['DRVR_LIC_TYPE_ID'].isin(["DRIVER LICENSE", "COMMERCIAL DRIVER LIC."])]

# %%
df_with_license
# Out:
#         CRASH_ID  UNIT_NBR  PRSN_NBR PRSN_TYPE_ID PRSN_OCCPNT_POS_ID  \
# 0       14768622         1         1       DRIVER         FRONT LEFT
# 1       14838637         1         1       DRIVER         FRONT LEFT
# 2       14838637         2         1       DRIVER         FRONT LEFT
# 3       14838641         1         1       DRIVER         FRONT LEFT
# 5       14838668         1         1       DRIVER         FRONT LEFT
# ...          ...       ...       ...          ...                ...
# 156945  15678580         3         1       DRIVER         FRONT LEFT
# 156948  15700059         1         1       DRIVER         FRONT LEFT
# 156950  15700059         3         1       DRIVER         FRONT LEFT
# 156951  15700064         1         1       DRIVER         FRONT LEFT
# 156953  15712435         1         1       DRIVER         FRONT LEFT
#
#        PRSN_INJRY_SEV_ID  PRSN_AGE PRSN_ETHNICITY_ID PRSN_GNDR_ID  \
# 0            NOT INJURED      27.0          HISPANIC         MALE
# ...

# %%
df_units_color=df_units[df_units['VEH_COLOR_ID'].isin(df_top_10_color)]

# %%
df_units_color
# Out:
#         CRASH_ID  UNIT_NBR   UNIT_DESC_ID VEH_PARKED_FL VEH_HNR_FL  \
# 0       14768622         1  MOTOR VEHICLE             N          N
# 1       14838637         1  MOTOR VEHICLE             N          N
# 2       14838637         2  MOTOR VEHICLE             N          N
# 3       14838637         2  MOTOR VEHICLE             N          N
# 5       14838641         1  MOTOR VEHICLE             N          N
# ...          ...       ...            ...           ...        ...
# 173494  15700059         2  MOTOR VEHICLE             N          N
# 173495  15700059         3  MOTOR VEHICLE             N          N
# 173496  15700064         1  MOTOR VEHICLE             N          N
# 173497  15700064         2  MOTOR VEHICLE             N          N
# 173498  15712435         1  MOTOR VEHICLE             N          Y
#
#        VEH_LIC_STATE_ID                VIN  VEH_MOD_YEAR VEH_COLOR_ID  \
# 0                    TX  4S2CK57D1X4381118        1999.0          GRY
# ...

# %%
df_units_color_state=df_units_color[df_units_color['VEH_LIC_STATE_ID'].isin(df_top_25_count_state)]

# %%
df_units_color_state
# Out:
#         CRASH_ID  UNIT_NBR   UNIT_DESC_ID VEH_PARKED_FL VEH_HNR_FL  \
# 0       14768622         1  MOTOR VEHICLE             N          N
# 1       14838637         1  MOTOR VEHICLE             N          N
# 2       14838637         2  MOTOR VEHICLE             N          N
# 3       14838637         2  MOTOR VEHICLE             N          N
# 5       14838641         1  MOTOR VEHICLE             N          N
# ...          ...       ...            ...           ...        ...
# 173494  15700059         2  MOTOR VEHICLE             N          N
# 173495  15700059         3  MOTOR VEHICLE             N          N
# 173496  15700064         1  MOTOR VEHICLE             N          N
# 173497  15700064         2  MOTOR VEHICLE             N          N
# 173498  15712435         1  MOTOR VEHICLE             N          Y
#
#        VEH_LIC_STATE_ID                VIN  VEH_MOD_YEAR VEH_COLOR_ID  \
# 0                    TX  4S2CK57D1X4381118        1999.0          GRY
# ...

# %%
df_charge_speed=df_charge[df_charge['CHARGE'].str.contains('SPEED',na=False)]

# %%
merge_speed_and_color_state=pd.merge(df_charge_speed,df_units_color_state,on='CRASH_ID')

# %%
merge_speed_and_color_state
# Out:
#        CRASH_ID  UNIT_NBR_x  PRSN_NBR                                CHARGE  \
# 0      14838834           1         1                 FAIL TO CONTROL SPEED
# 1      14838834           1         1                 FAIL TO CONTROL SPEED
# 2      14838834           1         1                 FAIL TO CONTROL SPEED
# 3      14838972           2         1                 FAIL TO CONTROL SPEED
# 4      14838972           2         1                 FAIL TO CONTROL SPEED
# ...         ...         ...       ...                                   ...
# 50788  15700059           1         1  FAIL TO CONTROL SPEED TO AVOID CRASH
# 50789  15700059           1         1  FAIL TO CONTROL SPEED TO AVOID CRASH
# 50790  15700064           1         1                 FAIL TO CONTROL SPEED
# 50791  15700064           1         1                 FAIL TO CONTROL SPEED
# 50792  15712435           1         1              FAILURE TO CONTROL SPEED
#
# ...

# %%
merge_speed_and_color_state_and_license=pd.merge(merge_speed_and_color_state,df_with_license,on='CRASH_ID')

# %%
merge_speed_and_color_state_and_license
# Out:
#         CRASH_ID  UNIT_NBR_x  PRSN_NBR_x  \
# 0       14838972           2           1
# 1       14838972           2           1
# 2       14838972           2           1
# 3       14838972           2           1
# 4       14838977           1           1
# ...          ...         ...         ...
# 107050  15700059           1           1
# 107051  15700059           1           1
# 107052  15700064           1           1
# 107053  15700064           1           1
# 107054  15712435           1           1
#
#                                       CHARGE CITATION_NBR  UNIT_NBR_y  \
# 0                      FAIL TO CONTROL SPEED      E010515           1
# 1                      FAIL TO CONTROL SPEED      E010515           1
# 2                      FAIL TO CONTROL SPEED      E010515           2
# 3                      FAIL TO CONTROL SPEED      E010515           2
# 4                               UNSAFE SPEED   TS00132638           1
# ...

# %%
merge_speed_and_color_state_and_license.groupby('VEH_MAKE_ID').count().sort_values(by='CRASH_ID',ascending=False)
# Out:
#                 CRASH_ID  UNIT_NBR_x  PRSN_NBR_x  CHARGE  CITATION_NBR  \
# VEH_MAKE_ID
# FORD               19212       19212       19212   19212         18846
# CHEVROLET          16866       16866       16866   16866         16588
# TOYOTA             11826       11826       11826   11826         11592
# DODGE               7941        7941        7941    7941          7784
# NISSAN              7329        7329        7329    7329          7187
# ...                  ...         ...         ...     ...           ...
# WINNEBAGO              2           2           2       2             2
# WORKHORSE              2           2           2       2             2
# ULTRA LITE MFG         1           1           1       1             1
# DATSUN                 1           1           1       1             1
# RENAULT                1           1           1       1             1
#
#                 UNIT_NBR_y  UNIT_DESC_ID  VEH_PARKED_FL  VEH_HNR_FL  \
# VEH_MAKE_ID
# ...
